# %% [markdown]
# # Artificial neural network (ANN) **Regression**

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# %% [markdown]
# Generating and plotting the data

# %%
N = 1000
X = np.random.random((N, 2))*6 - 3 # in between (-3, +3)
y = np.cos(2*X[:, 0]) + np.cos(3*X[:, 1]) # makes a saddle shape

# note: in this script "y" will be the target, "y_hat" will be prediction

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)
plt.show()

# %% [markdown]
# Building the model

# %%
model = tf.keras.models.Sequential()

# Adding first layer which has 128 nodes.
model.add(tf.keras.layers.Dense(128, input_shape = (2,), activation = 'relu'))

# Adding Output layer which has 1 node.
model.add(tf.keras.layers.Dense(1))

# %% [markdown]
# Compiling the model

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.01),
              loss = 'mse')

# %% [markdown]
# Training the model

# %%
r = model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - loss: 0.9559
# Epoch 2/100
# 32/32 [==============================] - 0s 937us/step - loss: 0.9794
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8933
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8896
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8659
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7450
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6614
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6696
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5915
# Epoch 10/100
# 32/32 [==============================] - 0s 954us/step - loss: 0.6032
# Epoch 11/100
# 32/32 [==============================] - 0s 975us/step - loss: 0.5625
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5647
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5154
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5593
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5317
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4873
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5178
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4860
# Epoch 19/100
# 32/32 [==============================] - 0s 978us/step - loss: 0.5125
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6206
# Epoch 21/100
# 32/32 [==============================] - 0s 941us/step - loss: 0.4967
# Epoch 22/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5225
# Epoch 23/100
# 32/32 [==============================] - 0s 980us/step - loss: 0.4816
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5122
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4485
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4848
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4969
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4336
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5342
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4741
# Epoch 31/100
# 32/32 [==============================] - 0s 986us/step - loss: 0.4633
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4614
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4739
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4439
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4508
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4298
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4236
# Epoch 38/100
# 32/32 [==============================] - 0s 971us/step - loss: 0.4491
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4818
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4156
# Epoch 41/100
# 32/32 [==============================] - 0s 948us/step - loss: 0.3739
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3882
# Epoch 43/100
# 32/32 [==============================] - 0s 916us/step - loss: 0.3335
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3351
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3092
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3226
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3149
# Epoch 48/100
# 32/32 [==============================] - 0s 848us/step - loss: 0.2904
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3175
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3167
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2825
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2903
# Epoch 53/100
# 32/32 [==============================] - 0s 929us/step - loss: 0.2352
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2292
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2223
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2232
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2336
# Epoch 58/100
# 32/32 [==============================] - 0s 982us/step - loss: 0.2084
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2264
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2015
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1926
# Epoch 62/100
# 32/32 [==============================] - 0s 969us/step - loss: 0.2057
# Epoch 63/100
# 32/32 [==============================] - 0s 953us/step - loss: 0.2130
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2700
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1685
# Epoch 66/100
# 32/32 [==============================] - 0s 921us/step - loss: 0.1435
# Epoch 67/100
# 32/32 [==============================] - 0s 925us/step - loss: 0.1360
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1226
# Epoch 69/100
# 32/32 [==============================] - 0s 888us/step - loss: 0.1172
# Epoch 70/100
# 32/32 [==============================] - 0s 998us/step - loss: 0.1219
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0899
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1185
# Epoch 73/100
# 32/32 [==============================] - 0s 955us/step - loss: 0.0697
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0655
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0531
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0477
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0506
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0620
# Epoch 79/100
# 32/32 [==============================] - 0s 988us/step - loss: 0.0399
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0434
# Epoch 81/100
# 32/32 [==============================] - 0s 956us/step - loss: 0.0366
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0201
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0201
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0158
# Epoch 86/100
# 32/32 [==============================] - 0s 992us/step - loss: 0.0190
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0217
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 89/100
# 32/32 [==============================] - 0s 979us/step - loss: 0.0126
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 91/100
# 32/32 [==============================] - 0s 944us/step - loss: 0.0104
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0106
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0136
# Epoch 94/100
# 32/32 [==============================] - 0s 805us/step - loss: 0.0117
# Epoch 95/100
# 32/32 [==============================] - 0s 713us/step - loss: 0.0100
# Epoch 96/100
# 32/32 [==============================] - 0s 891us/step - loss: 0.0097
# Epoch 97/100
# 32/32 [==============================] - 0s 727us/step - loss: 0.0145
# Epoch 98/100
# 32/32 [==============================] - 0s 725us/step - loss: 0.0165
# Epoch 99/100
# 32/32 [==============================] - 0s 758us/step - loss: 0.0099
# Epoch 100/100
# 32/32 [==============================] - 0s 993us/step - loss: 0.0119

# %% [markdown]
# Plotting the loss per iteration

# %%
plt.plot(r.history['loss'], label = 'loss')
plt.legend()

# %% [markdown]
# Plotting the prediction surface

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], y)

# Surface Plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
X_grid = np.vstack((xx.flatten(), yy.flatten())).T
y_hat = model.predict(X_grid).flatten()
ax.plot_trisurf(X_grid[:, 0], X_grid[:, 1], y_hat, linewidth = 0.2, antialiased = True)
plt.show()

# %% [markdown]
# Can it extrapolate?

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], y)

# Surface Plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
X_grid = np.vstack((xx.flatten(), yy.flatten())).T
y_hat = model.predict(X_grid).flatten()
ax.plot_trisurf(X_grid[:, 0], X_grid[:, 1], y_hat, linewidth = 0.2, antialiased = True)
plt.show()

# The regression model is “by construction” an interpolation model,
# and should not be used for extrapolation, unless this is properly justified.
